# %%
import json
with open(r"D:\Bridge_labz_practice\resourses\hdfc_loan_sample_20_rows.json",'r',encoding='utf-8') as f:
    data=json.load(f)

# %%
data
# Out:
# [{'Loan_ID': 'HDFC100001',
#   'Bank': 'HDFC Bank',
#   'Customer_Name': 'Rohan Verma',
#   'Gender': 'Male',
#   'Married': 'No',
#   'Dependents': 2,
#   'Education': 'Graduate',
#   'Employment_Status': 'Salaried',
#   'Applicant_Income': 56976,
#   'Coapplicant_Income': 0,
#   'Loan_Amount': 8031545,
#   'Loan_Term_Months': 360,
#   'Credit_History': 1,
#   'Property_Area': 'Urban',
#   'Age': 36,
#   'Loan_Status': 'Approved',
#   'CIBIL_Score': 699,
#   'Annual_Household_Income': 683712,
#   'Debt_to_Income_Ratio': 0.098,
#   'Purpose_of_Loan': 'Home',
#   'Existing_EMIs': 5610,
#   'Number_of_Previous_Loans': 0,
#   'Default_History_Count': 0,
#   'Employment_Length_Years': 1,
#   'Business_Type': None,
#   'Asset_Value': 744861,
#   'Guarantor': 'No',
#   'Co-signer_Relationship': 'Friend',
#   'Monthly_Expense': 30391,
#   'Organization_Type': 'Public',
#   'Region_Branch': 'KOL-004',
#   'Mobile_Verified': 'No',
#   'Email_Verified': 'Yes',
# ...

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
for i in data:
    my_dict=i
print(type(my_dict))
# Out:
# <class 'dict'>

# %%
my_json=json.dumps(my_dict,indent=2)
my_json
# Out:
# '{\n  "Loan_ID": "HDFC100020",\n  "Bank": "HDFC Bank",\n  "Customer_Name": "Rohan Verma",\n  "Gender": "Female",\n  "Married": "Yes",\n  "Dependents": 1,\n  "Education": "Not Graduate",\n  "Employment_Status": "Salaried",\n  "Applicant_Income": 43293,\n  "Coapplicant_Income": 51761,\n  "Loan_Amount": 7633475,\n  "Loan_Term_Months": 180,\n  "Credit_History": 1,\n  "Property_Area": "Semiurban",\n  "Age": 19,\n  "Loan_Status": "Approved",\n  "CIBIL_Score": 759,\n  "Annual_Household_Income": 1140648,\n  "Debt_to_Income_Ratio": 0.0,\n  "Purpose_of_Loan": "Home",\n  "Existing_EMIs": 0,\n  "Number_of_Previous_Loans": 1,\n  "Default_History_Count": 0,\n  "Employment_Length_Years": 2,\n  "Business_Type": null,\n  "Asset_Value": 3178586,\n  "Guarantor": "No",\n  "Co-signer_Relationship": null,\n  "Monthly_Expense": 49446,\n  "Organization_Type": "MNC",\n  "Region_Branch": "HYD-005",\n  "Mobile_Verified": "Yes",\n  "Email_Verified": "No",\n  "Institutional_Relationships": "RBI:Regulatory oversi
# ...
