# %%
#EMI Calculator

principal_entered = input("Enter Principal Amount:")
roi_entered = input("Enter ROI rate:")
years_entered = input("Enter Total Years:")

#validation of input

principal = principal_entered.isdigit() and int(principal_entered) or None
roi = roi_entered.isdigit() and float(roi) or None
years = years_entered.isdigit() and int(years_entered) or None

# %%
if (principal > 1 and roi > 1 and years > 1):
    interest_per_month = round(1*roi/(12*100),2)

    months = years*12
    emi = round(principal * interest_per_month * (1+interest_per_month)**months /
                ((1+interest_per_month) ** months -1),2)
    balance  = principal
